# %%
import pandas as pd
import mysql.connector
import matplotlib.pyplot as plt
import seaborn as sns

# %%
connection = mysql.connector.connect(
    host='localhost',
    user='alex',
    password='Leo@2567',
    database='price_flare'
)

query = "SELECT item_name item,price, DATE_FORMAT(date, '%Y-%m') AS date FROM tbl_prices A left join tbl_items B on A.item=B.id where date(date) between '2023-06-01' and '2023-06-30' group by date"
data = pd.read_sql(query, connection)
sns.scatterplot(x='date',y='price', hue='item', data=data)
# Out:
# /tmp/ipykernel_114197/1281591327.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, connection)
# <Axes: xlabel='date', ylabel='price'>

# %%
sns.lineplot(data=data, x="date",y="price", hue="item", style="item", markers=True, dashes=False)
# Out:
# <Axes: xlabel='date', ylabel='price'>

# %%
# sns.displot(x='date', data=data, kind='kde')
